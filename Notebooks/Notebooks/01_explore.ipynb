# %%
import pandas as pd

df1 = pd.read_csv('../datasets/Crimes_-_2001_to_Present.csv', low_memory=False)

print("=== CHICAGO CRIMES ===")
print("Rows:", df1.shape[0])
print("Columns:", df1.shape[1])
print("\nColumn names:")
print(df1.columns.tolist())
print("\nFirst 3 rows:")
print(df1.head(3))
print("\nMissing values:")
print(df1.isnull().sum())
# Out:
# === CHICAGO CRIMES ===
# Rows: 7784664
# Columns: 22
#
# Column names:
# ['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type', 'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude', 'Location']
#
# First 3 rows:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE  0870
# 2  11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE  0810
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 2        THEFT                OVER $500            RESIDENCE   False
#
# ...

# %%
df_la = pd.read_csv('../datasets/Crime_Data_from_2020_to_Present.csv', low_memory=False)

print("=== LA CRIME ===")
print("Rows:", df_la.shape[0])
print("Columns:", df_la.shape[1])
print("\nColumn names:")
print(df_la.columns.tolist())
print("\nFirst 3 rows:")
print(df_la.head(3))
# Out:
# === LA CRIME ===
# Rows: 757141
# Columns: 28
#
# Column names:
# ['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME', 'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes', 'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc', 'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1', 'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT', 'LON']
#
# First 3 rows:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  Southwest          377         2     624
# 1    Central          163         2     624
# 2    Central          155         2     845
#
# ...

# %%
df_temp     = pd.read_csv('../datasets/temperature.csv')
df_humidity = pd.read_csv('../datasets/humidity.csv')
df_wind     = pd.read_csv('../datasets/wind_speed.csv')
df_city     = pd.read_csv('../datasets/city_attributes.csv')

print("=== TEMPERATURE ===")
print("Columns:", df_temp.columns.tolist())
print(df_temp.head(3))

print("\n=== CITY ATTRIBUTES ===")
print(df_city.head(5))
# Out:
# === TEMPERATURE ===
# Columns: ['datetime', 'Vancouver', 'Portland', 'San Francisco', 'Seattle', 'Los Angeles', 'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque', 'Denver', 'San Antonio', 'Dallas', 'Houston', 'Kansas City', 'Minneapolis', 'Saint Louis', 'Chicago', 'Nashville', 'Indianapolis', 'Atlanta', 'Detroit', 'Jacksonville', 'Charlotte', 'Miami', 'Pittsburgh', 'Toronto', 'Philadelphia', 'New York', 'Montreal', 'Boston', 'Beersheba', 'Tel Aviv District', 'Eilat', 'Haifa', 'Nahariyya', 'Jerusalem']
#               datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0  2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1  2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2  2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque  ...  \
# 0          NaN         NaN         NaN         NaN          NaN  ...
# ...

# %%
df_census = pd.read_csv('../datasets/acs2017_census_tract_data.csv')

print("=== CENSUS ===")
print("Rows:", df_census.shape[0])
print("Columns:", df_census.shape[1])
print("\nColumn names:")
print(df_census.columns.tolist())
print("\nFirst 3 rows:")
print(df_census.head(3))
# Out:
# === CENSUS ===
# Rows: 74001
# Columns: 37
#
# Column names:
# ['TractId', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen', 'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty', 'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment']
#
# First 3 rows:
#       TractId    State          County  TotalPop   Men  Women  Hispanic  \
# 0  1001020100  Alabama  Autauga County      1845   899    946       2.4
# 1  1001020200  Alabama  Autauga County      2172  1167   1005       1.1
# 2  1001020300  Alabama  Autauga County      3385  1533   1852       8.0
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   86.3    5.2     0.0  ...   0.5          0.0         2.1         24.5
# ...

# %%
df_census_2015 = pd.read_csv('../datasets/acs2015_census_tract_data.csv')
df_census_2017 = pd.read_csv('../datasets/acs2017_census_tract_data.csv')

print("=== CENSUS 2015 ===")
print("Rows:", df_census_2015.shape[0])
print("Columns:", df_census_2015.shape[1])
print("\nColumn names:")
print(df_census_2015.columns.tolist())
print("\nFirst 3 rows:")
print(df_census_2015.head(3))

print("\n=== CENSUS 2017 ===")
print("Rows:", df_census_2017.shape[0])
print("Columns:", df_census_2017.shape[1])
print("\nColumn names:")
print(df_census_2017.columns.tolist())
print("\nFirst 3 rows:")
print(df_census_2017.head(3))
# Out:
# === CENSUS 2015 ===
# Rows: 74001
# Columns: 37
#
# Column names:
# ['CensusTract', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'Citizen', 'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty', 'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment']
#
# First 3 rows:
#    CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0   1001020100  Alabama  Autauga      1948   940   1008       0.9   87.4
# 1   1001020200  Alabama  Autauga      2156  1059   1097       0.8   40.4
# 2   1001020300  Alabama  Autauga      2968  1364   1604       0.0   74.5
#
#    Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# ...
